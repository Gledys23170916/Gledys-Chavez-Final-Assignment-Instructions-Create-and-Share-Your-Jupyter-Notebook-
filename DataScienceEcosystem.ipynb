# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**:
# - Convert minutes into hours
# - list the languages used in Data Science
# - Create table, and headings

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. **Python**: Data Analysis, Machine Learning, Deepl
# 2. **R**-: Statistic, visualization, academic research
# 3. **Sql**:Querying, extracting, merging data in databases
# 4. **Scala**: Big Data processing

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:1
# 1. **Pandas**: Dataframes, Cleaning, transforming
# 2. **Numpy**: Numerical computing and arrays
# 3. **Seaborn**: Statistical visualizations built in Matplotlib
# 4. **Plotly**: Interative charts and dashboards

# %% [markdown]
# ## Exercise 6 - Create a markdown cell with a table of Data Science tools
#
# | Data Science Tools |
# | --------------------|
# | MySQL |
# | Apache Casandra |
# | GitHub |
# | GitLab |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#7-introarithmetic.png

(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
min=200
a=60
hours=min/a
print("hours=", hours)
# Out:
# hours= 3.3333333333333335

# %% [markdown]
# ## Author
#    Gledys Chavez
